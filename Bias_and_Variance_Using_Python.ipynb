# %% [markdown]
# ###**Bias–Variance Decomposition**

# %%
# !pip install mlxtend

# %%
from mlxtend.evaluate import bias_variance_decomp
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Bias and Variance Using Python/student-mat.csv")
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]

predict = "G3"
x = np.array(data.drop(columns=[predict]))
y = np.array(data[predict])

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)

linear_regression = LinearRegression()
linear_regression.fit(xtrain, ytrain)
y_pred = linear_regression.predict(xtest)

# %%
data.head()
# Out:
#    G1  G2  G3  studytime  failures  absences
# 0   5   6   6          2         0         6
# 1   5   5   6          2         0         4
# 2   7   8  10          2         3        10
# 3  15  14  15          3         0         2
# 4   6  10  10          2         0         4

# %%
mse, bias, variance = bias_variance_decomp(linear_regression, xtrain, ytrain, xtest, ytest,
                                           loss='mse', num_rounds=200, random_seed=123)
print("Average Bias : ", bias)
print("Average Variance : ", variance)
# Out:
# Average Bias :  1.8784426899189428
# Average Variance :  0.06755655104291201

# %% [markdown]
# ###**Random Forest and Gradient Boosting with Bias–Variance Decomposition**

# %%
# !pip install mlxtend
from mlxtend.evaluate import bias_variance_decomp

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import train_test_split

# Load and prepare the data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Bias and Variance Using Python/student-mat.csv")
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]

predict = "G3"
x = np.array(data.drop(columns=[predict]))
y = np.array(data[predict])

# Split the data
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# Random Forest Regressor
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(xtrain, ytrain)

rf_mse, rf_bias, rf_var = bias_variance_decomp(
    rf, xtrain, ytrain, xtest, ytest,
    loss='mse', num_rounds=200, random_seed=42
)

print("🔸 Random Forest:")
print("MSE      :", rf_mse)
print("Bias^2   :", rf_bias)
print("Variance :", rf_var)
print()

# Gradient Boosting Regressor
gb = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
gb.fit(xtrain, ytrain)

gb_mse, gb_bias, gb_var = bias_variance_decomp(
    gb, xtrain, ytrain, xtest, ytest,
    loss='mse', num_rounds=200, random_seed=42
)

print("🔸 Gradient Boosting:")
print("MSE      :", gb_mse)
print("Bias^2   :", gb_bias)
print("Variance :", gb_var)
# Out:
# ...
# 🔸 Random Forest:
# MSE      : 3.2744425620858384
# Bias^2   : 2.7470803903356824
# Variance : 0.5273621717501585
#
# 🔸 Gradient Boosting:
# MSE      : 3.395654984548542
# Bias^2   : 2.893734007929555
# Variance : 0.5019209766189878
